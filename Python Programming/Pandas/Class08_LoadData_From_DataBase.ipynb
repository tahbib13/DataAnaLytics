# %%
import numpy as np
import pandas as pd

# %%
import mysql.connector as sqlc

# %% [markdown]
# #This is the you connect database with server

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password ="password1212",
  database ="mysqldb"
)

print(mydb)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x0000021D83756030>

# %%
mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM movies_db") #movies_db is the table name

records = mycursor.fetchall()

# %%
print(mycursor.description)
# Out:
# [('movie_id', 3, None, None, None, None, 1, 32768, 63), ('budget', 3, None, None, None, None, 1, 32768, 63), ('revenue', 5, None, None, None, None, 1, 32768, 63), ('unit', 252, None, None, None, None, 1, 16, 255), ('currency', 252, None, None, None, None, 1, 16, 255)]

# %%
column_names = [i[0] for i in mycursor.description]

df = pd.DataFrame(records, columns=column_names)

# %%
df.head()
# Out:
#    movie_id  budget  revenue      unit currency
# 0       101       1     12.5  Billions      INR
# 1       102     200    954.8  Millions      USD
# 2       103     165    644.8  Millions      USD
# 3       104     180    854.0  Millions      USD
# 4       105     250    670.0  Millions      USD
