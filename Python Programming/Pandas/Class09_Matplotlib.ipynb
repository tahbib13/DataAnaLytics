# %% [markdown]
# #What is Matplotlib?
#
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# Matplotlib was created by John D. Hunter.
#
#
# Matplotlib is open source and we can use it freely.
#
#
# Matplotlib is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.
#
# Canvas things can be intregrated by matplotlib.

# %%
import numpy as np
import pandas as pd

import matplotlib

print(matplotlib.__version__)
# Out:
# 3.9.2

# %%
import matplotlib.pyplot as plt

# %%
a = np.linspace(0,5, 11)
b = a ** 2

# %%
a
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
b
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# #Draw a line in a diagram from position (0,0) to position (6,250):

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# #Axis don't have any limitations

# %%
plt.plot(a, b)
plt.xlabel('This is X axis')
plt.ylabel("This is y axis")
plt.title("This is my first chart")
plt.show()

# %% [markdown]
# #Plotting x and y points
#
# The plot() function is used to draw points (markers) in a diagram.
#
#
# By default, the plot() function draws a line from point to point.
#
#
# The function takes parameters for specifying points in the diagram.
#
#
# Parameter 1 is an array containing the points on the x-axis.
#
#
# Parameter 2 is an array containing the points on the y-axis.
#
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# #Plotting Without Line
#
# To plot only the markers, you can use shortcut string notation parameter 'o', which means 'rings'.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# #Multiple Points

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# #Default X-Points
#
# If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc., depending on the length of the y-points.
#
# So, if we take the same example as above, and leave out the x-points, the diagram will look like this:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create first subplot (top-left)
plt.subplot(2, 2, 1)
plt.plot(x, y, 'r')  # Red line
plt.title("Red Sine Wave")

# Create second subplot (top-right)
plt.subplot(2, 2, 2)
plt.plot(x, y, 'g')  # Green line
plt.title("Green Sine Wave")

# Show the subplots
plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()

# %%
a = np.linspace(0,5, 11)
b = a ** 2

# %%
a
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
b
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(a, b)
plt.xlabel('This is X axis')
plt.ylabel("This is y axis")
plt.title("This is my first chart")
plt.show()

# %%
plt.subplot(2, 2, 1)
plt.plot(a, b, 'r')

plt.subplot(2,2,2)
plt.plot(b, a, 'g')

plt.subplot(2, 2, 3)
plt.plot(a, b, 'r')

plt.subplot(2,2,4)
plt.plot(b, a, 'g')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# #Mark Each Point circle shape

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# #Marker Size

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20) #ms set the marker size
plt.show()

# %% [markdown]
# #Marker Color

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %% [markdown]
# #From here we will fix the resolution of the output graph

# %%
fig = plt.figure()

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.plot(a, b, 'b')
axes.set_xlabel("X Axis")
axes.set_ylabel("y Axis")
axes.set_title("Object wise chart generating")
# Out:
# Text(0.5, 1.0, 'Object wise chart generating')

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 0.3, 0.3])

axes.plot(a, b, 'b')
axes.set_xlabel("X Axis")
axes.set_ylabel("y Axis")
axes.set_title("Object wise chart generating")
# Out:
# Text(0.5, 1.0, 'Object wise chart generating')

# %%
fig = plt.figure()

axes = fig.add_axes([0.1, 0.1, 1.8, 1.8])

axes.plot(a, b, 'b')
axes.set_xlabel("X Axis")
axes.set_ylabel("y Axis")
axes.set_title("Object wise chart generating")
# Out:
# Text(0.5, 1.0, 'Object wise chart generating')

# %% [markdown]
# #We will put another chart above chart.

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8,0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4,0.2])


axes1.plot(a, b, 'b')
axes1.set_xlabel("X Axis")
axes1.set_ylabel("y Axis")
axes1.set_title("Object wise chart generating")


axes2.plot(b, a, 'g')
axes2.set_xlabel("X Axis")
axes2.set_ylabel("y Axis")
axes2.set_title("Object wise chart generating")
# Out:
# Text(0.5, 1.0, 'Object wise chart generating')

# %% [markdown]
# #Now we will see functional call using objectal way format.

# %%
fig, axes = plt.subplots(3, 3)

# %%
fig, axes = plt.subplots(1, 2)

for x in axes:
    x.plot(a, b, 'r')
    x.set_xlabel('x')
    x.set_ylabel('y')
    x.set_title('This is a title')
    
fig

# %%
#fig = plt.figure(figsize=(8,4), dpi = 200)

fig, axes = plt.subplots(figsize=(8,4),dpi=100)

axes.plot(a, b, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('This is a title')
    
fig

# %%
#fig = plt.figure(figsize=(8,4), dpi = 100)

fig, axes = plt.subplots(figsize=(12,3),dpi=200)

axes.plot(a, b, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('This is a title')
    
fig

# %% [markdown]
# #Save the chart

# %%
fig.savefig("chart.png", dpi = 200)

# %%
fig = plt.figure()

pp = fig.add_axes([0,0,1,1])

pp.plot(a, a**2, label = 'A Squared Line')
pp.plot(a, a**3, label = 'A Cubed Line')
pp.legend(loc = 1)

# %%
fig = plt.figure()

pp = fig.add_axes([0,0,1,1])

pp.plot(a, a**2, label = 'A Squared Line')
pp.plot(a, a**3, label = 'A Cubed Line')
pp.legend(loc = 2)

# %%
fig = plt.figure()

pp = fig.add_axes([0,0,1,1])

pp.plot(a, a**2,color = '#cc00db' , label = 'A Squared Line')

pp.plot(a, a**3,color = '#cc00db', alpha = 0.8, label = 'A Squared Line')
pp.legend(loc = 1)

# %%
fig = plt.figure()

pp = fig.add_axes([0,0,1,1])

pp.plot(a, a**2,color = '#cc00db' , label = 'A Squared Line')

pp.plot(a, a**3,color = '#cc00db', alpha = 0.8, label = 'A Squared Line')
pp.legend(loc = 2)

# %% [markdown]
# #Different Data In the chart

# %%
fig, axes = plt.subplots(1, 3, figsize = (12,4))

axes[0].plot(a, a*5, a, a**3)
axes[0].set_title("this is my default chart")



axes[1].plot(b, b*10, b, b**2)
axes[1].axis('tight')
axes[1].set_title("this is my tight axes chart")


axes[2].plot(a, a**5, a, a**3)
axes[2].set_xlim([2,4])
#axes[2].set_ylim([500, 1000])
axes[2].set_title("this is custom axes range")
# Out:
# Text(0.5, 1.0, 'this is custom axes range')

# %% [markdown]
# #Scatter plot

# %%
plt.scatter(a,b)

# %% [markdown]
# #Histrogram

# %%
from random import sample

data = sample(range(1,1000), 100)

plt.hist(data)
# Out:
# (array([ 8., 10.,  8., 20.,  7.,  8.,  0., 12., 15., 12.]),
#  array([ 13. , 111.5, 210. , 308.5, 407. , 505.5, 604. , 702.5, 801. ,
#         899.5, 998. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #BOXPLOT GENERATING

# %%
data = [np.random.normal(0, std, 100) for std in range (1,4)] 

plt.boxplot(data, vert = True, patch_artist= True)
plt.show()

#BOXplot changing randomly

# %%
import pandas as pd

rain = pd.read_csv('labels.csv')
rain
# Out:
#     Label  July 2007  July 2020
# 0    1 Mo       4.75       0.12
# 1    3 Mo       4.98       0.11
# 2    6 Mo       5.08       0.13
# 3    1 Yr       5.01       0.14
# 4    2 Yr       4.89       0.16
# 5    3 Yr       4.89       0.17
# 6    5 Yr       4.95       0.28
# 7    7 Yr       4.99       0.46
# 8   10 Yr       5.05       0.62
# 9   20 Yr       5.21       1.09
# 10  30 Yr       5.14       1.31

# %%
fig, axes = plt.subplots(2,1, figsize = (12,8))

axes[0].plot(rain['Label'], rain['July 2007'], label = "Rainfall of July 2007")
axes[0].set_title("July 2007")

axes[1].plot(rain['Label'], rain['July 2020'], label = "Rainfall of July 2020")
axes[1].set_title("July 2020")

plt.show()

# %% [markdown]
# #Histogram

# %%
fig, axes = plt.subplots(2,1, figsize = (12,8))

axes[0].bar(rain['Label'], rain['July 2007'], label = "Rainfall of July 2007")
axes[0].set_title("July 2007")

axes[1].bar(rain['Label'], rain['July 2020'], label = "Rainfall of July 2020")
axes[1].set_title("July 2020")



plt.show()

# %% [markdown]
# #Scatter Plot

# %%
fig, axes = plt.subplots(2,1, figsize = (12,8))

axes[0].scatter(rain['Label'], rain['July 2007'], label = "Rainfall of July 2007")
axes[0].set_title("July 2007")

axes[1].scatter(rain['Label'], rain['July 2020'], label = "Rainfall of July 2020")
axes[1].set_title("July 2020")

plt.show()
