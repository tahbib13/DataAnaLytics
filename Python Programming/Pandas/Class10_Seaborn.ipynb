# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Visualize Distributions With Seaborn
#
# Seaborn is a library that uses Matplotlib underneath to plot graphs. It will be used to visualize random distributions.

# %% [markdown]
# #Distplots
#
# Distplot stands for distribution plot, it takes as input an array and plots a curve corresponding to the distribution of points in the array.

# %% [markdown]
# #Plotting a Distplot

# %%
sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_16812\2628693116.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5])

# %% [markdown]
# # Plotting a Distplot Without the Histogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_16812\2406393504.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5], hist=False)

# %%
df = pd.read_csv("dm_office_sales.csv")
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %% [markdown]
# # How to pick which chart is suitable :
#
# Link : https://www.youtube.com/watch?v=5jrsrSDEMxE

# %% [markdown]
# # When 2 variable and valus are Numeric that time we will plot them into scatter plot because relationship if positive or negative.

# %% [markdown]
# # Scatter Plot : Sales and Salary

# %%
sns.scatterplot(data = df, x = 'sales', y = 'salary');

# %%
plt.figure(figsize=(12,4), dpi = 150)
sns.scatterplot(data = df, x = 'sales', y = 'salary');

# %% [markdown]
# # Category wise relation

# %%
plt.figure(figsize=(12,4), dpi = 150)
sns.scatterplot(data = df, x = 'sales', y = 'salary', hue = 'division'); ##here division is category

# %%
plt.figure(figsize=(12,4), dpi = 150)
sns.scatterplot(data = df, x = 'sales', y = 'salary', hue = 'salary'); #here salary is category

# %%
plt.figure(figsize=(12,4), dpi = 150)
sns.scatterplot(data = df, x = 'sales', y = 'salary', hue = 'salary' ,s= 300); # bubble size fixing

# %%
plt.figure(figsize=(12,4), dpi = 150)
sns.scatterplot(data = df, x = 'sales', y = 'salary', hue = 'salary',
                size = 'work experience'); #size fix by data point work experience example when work exp 0 bubble small

# %%
plt.figure(figsize=(12,4), dpi = 150)
sns.scatterplot(data = df, x = 'sales', y = 'salary', hue = 'division',
                size = 'work experience', alpha = 0.8); #here alpha showing the transparacy

# %% [markdown]
# # Data point shape showing different

# %%
plt.figure(figsize=(12,6), dpi = 150)
sns.scatterplot(data = df, x = 'sales', y = 'salary',
                 style= 'level of education', s = 100, alpha = 0.9);
#Saving the image

plt.savefig('example_scatterplot.png')

# %%
sns.set_theme(style= 'darkgrid', palette= 'magma')

sns.scatterplot(data = df, x = 'sales', y = 'salary', hue = 'division',
                 style= 'level of education', s = 300, alpha = 0.7)
# Out:
# <Axes: xlabel='sales', ylabel='salary'>

# %%
sns.set_theme(style= 'ticks', palette= 'viridis')

sns.scatterplot(data = df, x = 'sales', y = 'salary', hue = 'division',
                 style= 'level of education', s = 300, alpha = 0.7)
# Out:
# <Axes: xlabel='sales', ylabel='salary'>

# %%
sns.set_theme(style= 'darkgrid', palette= 'magma')

sns.scatterplot(data = df, x = 'sales', y = 'salary', hue = 'division', s = 300, alpha = 0.7)
# Out:
# <Axes: xlabel='sales', ylabel='salary'>

# %% [markdown]
# # Histrogram :
#
# Normal Distribute means parametric analysis.
#
# If variable not follow the normal distribution then it will go to the non-parametric distribution .

# %%
sns.displot(data = df, x = 'salary');

# %%
sns.displot(data = df, x = 'salary', kde = True); #Bell shaped curve so this one is normal distribution

#kde means kernnel density estimation.

# %% [markdown]
# # Histogram

# %%
sns.histplot(data = df, x = 'salary');

# %%
sns.histplot(data = df, x = 'salary', bins = 5); #onle 5 bars use

# %%
df['division'].value_counts()
# Out:
# division
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: count, dtype: int64

# %% [markdown]
# # Countplot only 1 variable

# %%
plt.figure(figsize=(10,4), dpi = 150)
sns.countplot(data = df, x = 'division');

# %% [markdown]
# # Using Barplot 2 variable relation

# %%
plt.figure(figsize=(10,4), dpi = 150)
sns.barplot(data = df, x = 'division', y = 'salary');

# %%
plt.figure(figsize=(10,4), dpi = 150)
sns.barplot(data = df, x = 'division', y = 'salary' , hue = 'level of education');

# %%
sns.displot(data = df, y = 'sales');

# %% [markdown]
# # Boxplot

# %%
df = pd.read_csv("StudentsPerformance.csv")
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
sns.histplot(data = df, x = 'reading score')
# Out:
# <Axes: xlabel='reading score', ylabel='Count'>

# %%
sns.set_theme(style= 'white')
sns.boxplot(data = df, x = 'reading score');

# %%
sns.set_theme(style= 'white')
sns.boxplot(data = df, x = 'reading score',color='green');

# %% [markdown]
# # Quartile showing

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Sample data (replace df['reading score'] with your actual column)
data = df['reading score']

# Set theme style to 'white'
sns.set_theme(style='white')

# Create a horizontal boxplot
ax = sns.boxplot(data=data, color='pink', orient='h')

# Calculate quartiles
q1 = np.percentile(data, 25)
q2 = np.percentile(data, 50)  # Median
q3 = np.percentile(data, 75)

# Annotate the quartiles horizontally
plt.text(q1, 0.1, '25%', color='black', ha='center', va='bottom')
plt.text(q2, 0.1, '50%', color='black', ha='center', va='bottom')
plt.text(q3, 0.1, '75%', color='black', ha='center', va='bottom')

# Show plot
plt.show()

# %% [markdown]
# # Terms of hue or Divided by different categories.

# %%
plt.figure(figsize=(10,4), dpi = 150)
sns.set_theme(style= 'white')
sns.boxplot(data = df, x = 'parental level of education', y = 'math score',
            hue = 'parental level of education');

# %%
plt.figure(figsize=(10,4), dpi = 150)
sns.set_theme(style= 'white')
sns.boxplot(data = df, x = 'parental level of education', y = 'math score',
            hue = 'parental level of education');

# %%
plt.figure(figsize=(10,4), dpi = 150)
sns.set_theme(style= 'white')
sns.boxplot(data = df, x = 'parental level of education', y = 'math score',
            hue = 'gender');

# %% [markdown]
# # Question like how many distribution how many out layers , ans will generate by boxplot.

# %% [markdown]
# # Boxplot is the way of find out which kind of distribution is this.

# %% [markdown]
# # Normal (Gaussian) Distribution(Bell shaped Curve)
#
# The Normal Distribution is one of the most important distributions.
#
# It is also called the Gaussian Distribution after the German mathematician Carl Friedrich Gauss.
#
# It fits the probability distribution of many events, eg. IQ Scores, Heartbeat etc.
#
# Use the random.normal() method to get a Normal Data Distribution.
#
# It has three parameters:
#
# loc - (Mean) where the peak of the bell exists.
#
# scale - (Standard Deviation) how flat the graph distribution should be.
#
# size - The shape of the returned array.

# %%
from numpy import random

x = random.normal(size=(2, 3))

print(x) #Generate a random normal distribution of size 2x3:
# Out:
# [[ 1.11150264  1.09727788  0.41141931]
#  [-1.21157001 -1.80436584  1.12769479]]

# %%
#Generate a random normal distribution of size 2x3 with mean at 1 and standard deviation of 2:

from numpy import random

x = random.normal(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[ 1.89196491  0.76577682 -2.38506829]
#  [-0.24617166  2.79645048 -0.97426886]]

# %% [markdown]
# # Visualization of Normal Distribution

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(size=1000), hist=False)

plt.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_16812\2253916830.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist=False)
