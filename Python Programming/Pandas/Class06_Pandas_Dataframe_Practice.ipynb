# %% [markdown]
# #What is a DataFrame?
#
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %%
import numpy as np
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
#refer to the row index:
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
#use a list of indexes:
print(df.loc[[0, 1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
import numpy as np
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])

print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
#refer to the named index:
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
np.random.seed(101)
x = np.random.randint(0, 101, (4,3))
x
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
p = pd.DataFrame(x, columns= ['Polash', 'Mukul', 'Akbar'])
p
# Out:
#    Polash  Mukul  Akbar
# 0      95     11     81
# 1      70     63     87
# 2      75      9     77
# 3      40      4     63

# %%
x = np.arange(1,11)
y = np.arange(2,12)

pd.DataFrame({'Jamal':x ,'Kamal':y})
# Out:
#    Jamal  Kamal
# 0      1      2
# 1      2      3
# 2      3      4
# 3      4      5
# 4      5      6
# 5      6      7
# 6      7      8
# 7      8      9
# 8      9     10
# 9     10     11

# %%
A = np.arange(1,21)
B = np.arange(2,22)




pd.DataFrame({'X':A ,'Y':B})
# Out:
#      X   Y
# 0    1   2
# 1    2   3
# 2    3   4
# 3    4   5
# 4    5   6
# 5    6   7
# 6    7   8
# 7    8   9
# 8    9  10
# 9   10  11
# 10  11  12
# 11  12  13
# 12  13  14
# 13  14  15
# 14  15  16
# 15  16  17
# 16  17  18
# 17  18  19
# 18  19  20
# 19  20  21

# %%
pwd #working directory find out
# Out:
# 'd:\\Data Science and Machine Learning Course\\Practice'

# %%
df = pd.read_csv('tips.csv')

print(df)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34   1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01   3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68   3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59   3.61  Female     No   Sun  Dinner     4              6.15
# 5         25.29   4.71    Male     No   Sun  Dinner     4              6.32
# 6          8.77   2.00    Male     No   Sun  Dinner     2              4.38
# 7         26.88   3.12    Male     No   Sun  Dinner     4              6.72
# 8         15.04   1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78   3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27   1.71    Male     No   Sun  Dinner     2              5.14
# ...

# %%
import pandas as pd

df = pd.read_csv('tips.csv')

print(df.to_string())
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person             Payer Name     CC Number Payment ID
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49     Christy Cunningham  3.560000e+15    Sun2959
# 1         10.34   1.66    Male     No   Sun  Dinner     3              3.45         Douglas Tucker  4.480000e+15    Sun4608
# 2         21.01   3.50    Male     No   Sun  Dinner     3              7.00         Travis Walters  6.010000e+15    Sun4458
# 3         23.68   3.31    Male     No   Sun  Dinner     2             11.84       Nathaniel Harris  4.680000e+15    Sun5260
# 4         24.59   3.61  Female     No   Sun  Dinner     4              6.15           Tonya Carter  4.830000e+15    Sun2251
# 5         25.29   4.71    Male     No   Sun  Dinner     4              6.32             Erik Smith  2.130000e+14    Sun9679
# ...

# %% [markdown]
# #max_rows
#
# The number of rows returned is defined in Pandas option settings.
#
# You can check your system's maximum rows with the pd.options.display.max_rows statement.

# %%
import pandas as pd

print(pd.options.display.max_rows)
# Out:
# None

# %%
import pandas as pd

print(pd.options.display.max_columns)
# Out:
# None

# %% [markdown]
# #Increase the maximum number of rows to display the entire DataFrame:

# %%
import pandas as pd

pd.options.display.max_rows = 9999

df = pd.read_csv('tips.csv')

print(df)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34   1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01   3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68   3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59   3.61  Female     No   Sun  Dinner     4              6.15
# 5         25.29   4.71    Male     No   Sun  Dinner     4              6.32
# 6          8.77   2.00    Male     No   Sun  Dinner     2              4.38
# 7         26.88   3.12    Male     No   Sun  Dinner     4              6.72
# 8         15.04   1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78   3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27   1.71    Male     No   Sun  Dinner     2              5.14
# ...

# %% [markdown]
# #Pandas - Analyzing DataFrames

# %% [markdown]
# #Viewing the Data
#
# One of the most used method for getting a quick overview of the DataFrame, is the head() method.
#
#
# The head() method returns the headers and a specified number of rows, starting from the top.

# %%
import pandas as pd

# Adjust settings to display all columns without truncation
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_rows', None)     # Display all rows (if needed)
pd.set_option('display.width', None)        # Make sure it fits to screen width

# Read the CSV file
df = pd.read_csv('tips.csv')

# Print the first 10 rows row-wise
print(df.head(10).to_string())
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person          Payer Name     CC Number Payment ID
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49  Christy Cunningham  3.560000e+15    Sun2959
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45      Douglas Tucker  4.480000e+15    Sun4608
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00      Travis Walters  6.010000e+15    Sun4458
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84    Nathaniel Harris  4.680000e+15    Sun5260
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15        Tonya Carter  4.830000e+15    Sun2251
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32          Erik Smith  2.130000e+14    Sun9679
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38  Kristopher Johnson  2.220000e+15    Sun5985
# ...

# %% [markdown]
# #Last  Rows print

# %%
import pandas as pd

# Adjust settings to display all columns without truncation
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.max_rows', None)     # Display all rows (if needed)
pd.set_option('display.width', None)        # Make sure it fits to screen width

# Read the CSV file
df = pd.read_csv('tips.csv')

# Print the first 10 rows row-wise
print(df.tail(5).to_string())
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person       Payer Name     CC Number Payment ID
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68    Michael Avila  5.300000e+15    Sat2657
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59   Monica Sanders  3.510000e+15    Sat1766
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34       Keith Wong  6.010000e+15    Sat3880
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91     Dennis Dixon  4.380000e+12      Sat17
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39  Michelle Hardin  3.510000e+15    Thur672

# %% [markdown]
# #Info About the Data

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    float64
#  10  Payment ID        244 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 21.1+ KB
# None

# %% [markdown]
# #Pandas - Cleaning Data

# %% [markdown]
# #Data Cleaning
#
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# #Empty cells
#
# #Data in wrong format
#
# #Wrong data
#
# #Duplicates
#
# In this tutorial you will learn how to deal with all of them.

# %% [markdown]
# #Remove Rows

# %%
import pandas as pd

df = pd.read_csv('tips.csv')

new_df = df.dropna()

print(new_df.to_string())
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person             Payer Name     CC Number Payment ID
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49     Christy Cunningham  3.560000e+15    Sun2959
# 1         10.34   1.66    Male     No   Sun  Dinner     3              3.45         Douglas Tucker  4.480000e+15    Sun4608
# 2         21.01   3.50    Male     No   Sun  Dinner     3              7.00         Travis Walters  6.010000e+15    Sun4458
# 3         23.68   3.31    Male     No   Sun  Dinner     2             11.84       Nathaniel Harris  4.680000e+15    Sun5260
# 4         24.59   3.61  Female     No   Sun  Dinner     4              6.15           Tonya Carter  4.830000e+15    Sun2251
# 5         25.29   4.71    Male     No   Sun  Dinner     4              6.32             Erik Smith  2.130000e+14    Sun9679
# ...

# %% [markdown]
# #Random Row

# %%
df.sample()
# Out:
#      total_bill   tip     sex smoker   day   time  size  price_per_person  \
# 121       13.42  1.68  Female     No  Thur  Lunch     2              6.71
#
#        Payer Name     CC Number Payment ID
# 121  Laura Garcia  5.180000e+15   Thur2158

# %%
#10 random row

df.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 34        17.78  3.27    Male     No   Sat  Dinner     2              8.89
# 71        17.07  3.00  Female     No   Sat  Dinner     3              5.69
# 156       48.17  5.00    Male     No   Sun  Dinner     6              8.03
# 130       19.08  1.50    Male     No  Thur   Lunch     2              9.54
# 66        16.45  2.47  Female     No   Sat  Dinner     2              8.22
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 126        8.52  1.48    Male     No  Thur   Lunch     2              4.26
# 196       10.34  2.00    Male    Yes  Thur   Lunch     2              5.17
# 36        16.31  2.00    Male     No   Sat  Dinner     3              5.44
# 110       14.00  3.00    Male     No   Sat  Dinner     2              7.00
#
#          Payer Name     CC Number Payment ID
# 34   Jacob Castillo  3.550000e+15    Sat8124
# 71    Teresa Fisher  5.440000e+15    Sat3469
# ...

# %% [markdown]
# #DataFrame Size

# %%
df.shape
# Out:
# (244, 11)

# %% [markdown]
# #Specific Column selection :

# %%
df["sex"]
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
# 5        Male
# 6        Male
# 7        Male
# 8        Male
# 9        Male
# 10       Male
# 11     Female
# 12       Male
# 13       Male
# 14     Female
# 15       Male
# 16     Female
# 17       Male
# 18     Female
# 19       Male
# 20       Male
# 21     Female
# 22     Female
# 23       Male
# 24       Male
# 25       Male
# 26       Male
# 27       Male
# 28       Male
# 29     Female
# 30       Male
# 31       Male
# 32     Female
# 33     Female
# 34       Male
# 35       Male
# 36       Male
# 37     Female
# 38       Male
# 39       Male
# 40       Male
# 41       Male
# 42       Male
# 43       Male
# 44       Male
# 45       Male
# 46       Male
# 47       Male
# 48       Male
# 49       Male
# 50       Male
# 51     Female
# 52     Female
# 53       Male
# 54       Male
# 55       Male
# 56       Male
# 57     Female
# 58       Male
# 59       Male
# 60       Male
# 61       Male
# ...

# %% [markdown]
# #Multiple Column:

# %%
df[["sex","smoker","time"]]
# Out:
#         sex smoker    time
# 0    Female     No  Dinner
# 1      Male     No  Dinner
# 2      Male     No  Dinner
# 3      Male     No  Dinner
# 4    Female     No  Dinner
# 5      Male     No  Dinner
# 6      Male     No  Dinner
# 7      Male     No  Dinner
# 8      Male     No  Dinner
# 9      Male     No  Dinner
# 10     Male     No  Dinner
# 11   Female     No  Dinner
# 12     Male     No  Dinner
# 13     Male     No  Dinner
# 14   Female     No  Dinner
# 15     Male     No  Dinner
# 16   Female     No  Dinner
# 17     Male     No  Dinner
# 18   Female     No  Dinner
# 19     Male     No  Dinner
# 20     Male     No  Dinner
# 21   Female     No  Dinner
# 22   Female     No  Dinner
# 23     Male     No  Dinner
# 24     Male     No  Dinner
# 25     Male     No  Dinner
# 26     Male     No  Dinner
# 27     Male     No  Dinner
# 28     Male     No  Dinner
# 29   Female     No  Dinner
# 30     Male     No  Dinner
# 31     Male     No  Dinner
# 32   Female     No  Dinner
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %% [markdown]
# #ALL ROW and Specific Columns

# %%
df.iloc[:,[0,1,3]]
# Out:
#      total_bill    tip smoker
# 0         16.99   1.01     No
# 1         10.34   1.66     No
# 2         21.01   3.50     No
# 3         23.68   3.31     No
# 4         24.59   3.61     No
# 5         25.29   4.71     No
# 6          8.77   2.00     No
# 7         26.88   3.12     No
# 8         15.04   1.96     No
# 9         14.78   3.23     No
# 10        10.27   1.71     No
# 11        35.26   5.00     No
# 12        15.42   1.57     No
# 13        18.43   3.00     No
# 14        14.83   3.02     No
# 15        21.58   3.92     No
# 16        10.33   1.67     No
# 17        16.29   3.71     No
# 18        16.97   3.50     No
# 19        20.65   3.35     No
# 20        17.92   4.08     No
# 21        20.29   2.75     No
# 22        15.77   2.23     No
# 23        39.42   7.58     No
# 24        19.82   3.18     No
# 25        17.81   2.34     No
# 26        13.37   2.00     No
# 27        12.69   2.00     No
# 28        21.70   4.30     No
# 29        19.65   3.00     No
# ...

# %% [markdown]
# #ALL COLUMN and Specific Rows

# %%
df.iloc[0:51,:]
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0        16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1        10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2        21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4        24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5        25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6         8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7        26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8        15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9        14.78  3.23    Male     No  Sun  Dinner     2              7.39
# 10       10.27  1.71    Male     No  Sun  Dinner     2              5.14
# 11       35.26  5.00  Female     No  Sun  Dinner     4              8.82
# ...

# %% [markdown]
# #Condition for seeing data

# %%
tips_over_5 = df[df['tip'] > 5]

# %% [markdown]
# #Multiple condition

# %%
filtering_cond = (df['tip'] > 5) & (df['day'] == "Sat")


tips_over_5 = df[filtering_cond]
tips_over_5
# Out:
#      total_bill    tip     sex smoker  day    time  size  price_per_person  \
# 23        39.42   7.58    Male     No  Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No  Sat  Dinner     4             12.07
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3             16.94
# 211       25.89   5.16    Male    Yes  Sat  Dinner     4              6.47
# 212       48.33   9.00    Male     No  Sat  Dinner     4             12.08
# 214       28.17   6.50  Female    Yes  Sat  Dinner     3              9.39
# 239       29.03   5.92    Male     No  Sat  Dinner     3              9.68
#
#           Payer Name     CC Number Payment ID
# 23    Lance Peterson  3.540000e+15     Sat239
# 59       Brian Ortiz  6.600000e+15    Sat8139
# 170    Gregory Clark  5.470000e+15    Sat1954
# 211   Christopher Li  6.010000e+15    Sat6735
# 212  Alex Williamson  6.760000e+11    Sat4590
# 214  Marissa Jackson  4.920000e+15    Sat3374
# ...

# %% [markdown]
# #MaximumTips Value

# %%
df["tip"].max()
# Out:
# 10.0

# %% [markdown]
# #MinimumTips Value

# %%
df["tip"].min()
# Out:
# 1.0

# %% [markdown]
# #ALL INFO min,max,sum.........etc

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563313e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369139e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040000e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525000e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.552500e+15
# max     50.810000   10.000000    6.000000         20.270000  6.600000e+15

# %%
df.describe().transpose() #reverse hbe
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563313e+15  2.369139e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040000e+13  3.525000e+15  4.552500e+15  6.600000e+15

# %% [markdown]
# #Value Counts Functions

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['tip'].value_counts()
# Out:
# tip
# 2.00     33
# 3.00     23
# 4.00     12
# 5.00     10
# 2.50     10
# 1.50      9
# 3.50      9
# 1.00      4
# 3.48      3
# 1.25      3
# 3.18      2
# 4.30      2
# 1.44      2
# 2.01      2
# 2.75      2
# 6.50      2
# 2.31      2
# 2.24      2
# 3.76      2
# 2.23      2
# 2.20      2
# 4.08      2
# 3.25      2
# 2.03      2
# 3.23      2
# 5.14      1
# 2.74      1
# 1.73      1
# 1.63      1
# 2.55      1
# 1.36      1
# 2.30      1
# 6.70      1
# 1.80      1
# 5.07      1
# 3.75      1
# 2.83      1
# 2.18      1
# 2.92      1
# 1.68      1
# 2.52      1
# 1.48      1
# 4.20      1
# 1.01      1
# 3.55      1
# 2.61      1
# 4.50      1
# 5.92      1
# 4.67      1
# 1.17      1
# 1.47      1
# 3.39      1
# 2.88      1
# 2.72      1
# 1.58      1
# 1.92      1
# 3.09      1
# 1.10      1
# 9.00      1
# 5.16      1
# 3.41      1
# 2.02      1
# 2.56      1
# 4.19      1
# 5.65      1
# 3.68      1
# 4.06      1
# 3.11      1
# 5.15      1
# 3.16      1
# 10.00     1
# ...

# %% [markdown]
# #Unique Value

# %%
df["Payer Name"].unique()
# Out:
# array(['Christy Cunningham', 'Douglas Tucker', 'Travis Walters',
#        'Nathaniel Harris', 'Tonya Carter', 'Erik Smith',
#        'Kristopher Johnson', 'Robert Buck', 'Joseph Mcdonald',
#        'Jerome Abbott', 'William Riley', 'Diane Macias',
#        'Chad Harrington', 'Joshua Jones', 'Vanessa Jones',
#        'Matthew Reilly', 'Elizabeth Foster', 'John Pittman',
#        'Laura Martinez', 'Timothy Oneal', 'Thomas Rice',
#        'Natalie Gardner', 'Ashley Shelton', 'Lance Peterson',
#        'Christopher Ross', 'Robert Perkins', 'Kyle Avery',
#        'Patrick Barber', 'David Collier', 'Melinda Murphy', 'Grant Hall',
#        'Danny Santiago', 'Amanda Wilson', 'Amber Francis',
#        'Jacob Castillo', 'Joseph Mullins', 'William Ford', 'Erin Lewis',
#        'Brandon Bradley', 'Mr. Brandon Berry', 'Adam Edwards',
#        'David Boyer', 'Bryan Brown', 'Christopher Spears', 'Todd Cooper',
#        'Richard Fitzgerald', 'Joshua Gilmore', 'James Barnes',
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID',
#        'total_amt'],
#       dtype='object')

# %% [markdown]
# #New_Columns

# %%
df.loc[:, "total_amt"] = df["total_bill"] + df["tip"]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name     CC Number Payment ID  total_amt
# 0  Christy Cunningham  3.560000e+15    Sun2959      18.00
# 1      Douglas Tucker  4.480000e+15    Sun4608      12.00
# 2      Travis Walters  6.010000e+15    Sun4458      24.51
# 3    Nathaniel Harris  4.680000e+15    Sun5260      26.99
# 4        Tonya Carter  4.830000e+15    Sun2251      28.20

# %% [markdown]
# #upto 2decimal point

# %%
import numpy as np
df['total_amt'] = np.round(df['total_amt'],2)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name     CC Number Payment ID  total_amt
# 0  Christy Cunningham  3.560000e+15    Sun2959       18.0
# 1      Douglas Tucker  4.480000e+15    Sun4608       12.0
# 2      Travis Walters  6.010000e+15    Sun4458       25.0
# 3    Nathaniel Harris  4.680000e+15    Sun5260       27.0
# 4        Tonya Carter  4.830000e+15    Sun2251       28.0

# %% [markdown]
# #Column Delete

# %%
df.drop(['total_amt'], axis=1) #axis 1 means column drop
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34   1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01   3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68   3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59   3.61  Female     No   Sun  Dinner     4              6.15
# 5         25.29   4.71    Male     No   Sun  Dinner     4              6.32
# 6          8.77   2.00    Male     No   Sun  Dinner     2              4.38
# 7         26.88   3.12    Male     No   Sun  Dinner     4              6.72
# 8         15.04   1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78   3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27   1.71    Male     No   Sun  Dinner     2              5.14
# ...

# %% [markdown]
# #ROW DELETE

# %%
#Row Drop

df.drop(index=range(0,21)) #0 to 21 column drop
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 21        20.29   2.75  Female     No   Sat  Dinner     2             10.14
# 22        15.77   2.23  Female     No   Sat  Dinner     2              7.88
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 24        19.82   3.18    Male     No   Sat  Dinner     2              9.91
# 25        17.81   2.34    Male     No   Sat  Dinner     4              4.45
# 26        13.37   2.00    Male     No   Sat  Dinner     2              6.68
# 27        12.69   2.00    Male     No   Sat  Dinner     2              6.34
# 28        21.70   4.30    Male     No   Sat  Dinner     2             10.85
# 29        19.65   3.00  Female     No   Sat  Dinner     2              9.82
# 30         9.55   1.45    Male     No   Sat  Dinner     2              4.78
# 31        18.35   2.50    Male     No   Sat  Dinner     4              4.59
# ...

# %% [markdown]
# #When title in first row,we have to skip that row

# %%
df = pd.read_csv('updated_tips.csv',skiprows=1)

# %%
print(df.to_string)
# Out:
# <bound method DataFrame.to_string of     total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0        16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1        10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2        21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4        24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5        25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6         8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7        26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8        15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9        14.78  3.23    Male     No  Sun  Dinner     2              7.39
# 10       10.27  1.71    Male     No  Sun  Dinner     2              5.14
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        50 non-null     float64
#  1   tip               50 non-null     float64
#  2   sex               50 non-null     object
#  3   smoker            50 non-null     object
#  4   day               50 non-null     object
#  5   time              50 non-null     object
#  6   size              50 non-null     int64
#  7   price_per_person  50 non-null     float64
#  8   Payer Name        50 non-null     object
#  9   CC Number         50 non-null     float64
#  10  Payment ID        50 non-null     object
#  11  total_amt         50 non-null     float64
# dtypes: float64(5), int64(1), object(6)
# memory usage: 4.8+ KB

# %%
#Column ADD

df.loc[:, "total_amt"] = df["total_bill"] + df["tip"]

# %%
df
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0        16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1        10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2        21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3        23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4        24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5        25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6         8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7        26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8        15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9        14.78  3.23    Male     No  Sun  Dinner     2              7.39
# 10       10.27  1.71    Male     No  Sun  Dinner     2              5.14
# 11       35.26  5.00  Female     No  Sun  Dinner     4              8.82
# ...

# %% [markdown]
# ##New File after update everything creating

# %%
df.to_csv('Newupdated_tips.csv', index=False)
